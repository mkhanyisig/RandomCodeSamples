// %%
Map VARIANT_IMPACT_COLORS = ["deletion": '#ED8B00', "duplication": '#333F48', "frameshift": '#A2AAAD',
                                 "fusion"  : '#0085CA', "indel": '#9467bd', "insertion": '#43B02A', "missense": '#002D72',
                                 "none"    : '#7f7f7f', "nonsense": '#bcbd22', "splice site": '#17becf', "unknown": '#D0D3D4']

def availableColors = VARIANT_IMPACT_COLORS.collect { key,value ->
    Map mp = [:]
    mp.put('color', value)
    mp.put('value', key)
    mp
}

List JAX_BRAND_COLORS = ['#0085CA', '#002D72', '#2C2A29', '#333F48', '#A2AAAD', '#D0D3D4', '#FFFFFF',
                        '#F1C400', '#ED8B00', '#DC582A', '#AB2328', '#8A1B61', '#005151', '#43B02A']

 
beakerx.impact_colors = ["availableColors": availableColors.collect {it}]
beakerx.jax_colors = ["colors": JAX_BRAND_COLORS]

// %% [markdown]
// # JAX Brand Colors with Opacity

// %%
List opacityValues = [1,0.75,0.5,0.25]

def JAX_BRAND_COLORS_WITH_FILTER = [
        [
            'color': '#0085CA',
            'tint': opacityValues
        ],
        [
            'color': '#002D72',
            'tint': opacityValues
        ],
        [
            'color': '#2C2A29',
            'tint': opacityValues
        ],
        [
            'color': '#333F48',
            'tint': opacityValues
        ],
        [
            'color': '#A2AAAD',
            'tint': opacityValues
        ],
        [
            'color': '#D0D3D4',
            'tint': opacityValues
        ],
        [
            'color': '#FFFFFF',
            'tint': opacityValues
        ],
        [
            'color': '#F1C400',
            'tint': opacityValues
        ],
        [
            'color': '#ED8B00',
            'tint': opacityValues
        ],
        [
            'color': '#DC582A',
            'tint': opacityValues
        ],
        [
            'color': '#AB2328',
            'tint': opacityValues
        ],
        [
            'color': '#8A1B61',
            'tint': opacityValues
        ],
        [
            'color': '#005151',
            'tint': opacityValues
        ],
        [
            'color': '#43B02A',
            'tint':  opacityValues
        ]
    ]
beakerx.jax_colors_with_tint = ["jax_colors_with_tint": JAX_BRAND_COLORS_WITH_FILTER]

// %%
%%html
<div class="colors row">
    <div class="col-sm-10">
        <h3>JAX Colors with Tint</h3>
        <table class="jax_brand table table-bordered">
            <thead>
                <tr>
                    <th>Color Code</th>
                    <th>Color</th>
                    <th>Tint (100%)</th>
                    <th>Tint (75%)</th>
                    <th>Tint (50%)</th>
                    <th>Tint (25%)</th>
                </tr>
            </thead>
            <tbody>
                <tr></tr>
            </tbody>
        </table>
    </div>
      
</div>
<hr>
<div class="row">
        <div class="col-sm-3">
        <h3>Protein Effect</h3>
        <table class="protein_effect table table-bordered">
            <thead>
                <tr>
                    <th>Protein Effect</th>
                    <th>Color</th>
                </tr>
            </thead>
            <tbody>
                <tr></tr>
            </tbody>
        </table>
    </div>
    <div class='col-sm-1'></div>
    <div class="col-sm-3">
        <h3>Impact</h3>
        <table class="impact table table-bordered">
            <thead>
                <tr>
                    <th>Impact</th>
                    <th>Color</th>
                </tr>
            </thead>
            <tbody>
                <tr></tr>
            </tbody>
        </table>
     </div>
    <div class='col-sm-1'></div>
    <div class="col-sm-4">
        <h3>Approval Status</h3>
        <table class="approval_status table table-bordered">
            <thead>
                <tr>
                    <th>Impact</th>
                    <th>Color</th>
                </tr>
            </thead>
            <tbody>
                <tr></tr>
            </tbody>
        </table>
     </div>

</div>
// Out:
// <html><div class="colors row">
//     <div class="col-sm-10">
//         <h3>JAX Colors with Tint</h3>
//         <table class="jax_brand table table-bordered">
//             <thead>
//                 <tr>
//                     <th>Color Code</th>
//                     <th>Color</th>
//                     <th>Tint (100%)</th>
//                     <th>Tint (75%)</th>
//                     <th>Tint (50%)</th>
//                     <th>Tint (25%)</th>
//                 </tr>
//             </thead>
//             <tbody>
//                 <tr></tr>
//             </tbody>
//         </table>
//     </div>
//
// </div>
// <hr>
// <div class="row">
//         <div class="col-sm-3">
//         <h3>Protein Effect</h3>
//         <table class="protein_effect table table-bordered">
//             <thead>
//                 <tr>
//                     <th>Protein Effect</th>
//                     <th>Color</th>
//                 </tr>
//             </thead>
// ...

// %%
%%js

var jax_brand_core_body = $('.jax_brand_core tbody'),
    jax_with_tint_body = $('.jax_brand tbody');

jax_with_tint_body.html('')
jax_brand_core_body.html('')

var jaxColors = beakerx.jax_colors.colors,
    jaxColorsWithTint = beakerx.jax_colors_with_tint.jax_colors_with_tint;


for (var i = 0; i < jaxColorsWithTint.length; i++) {
    var current = jaxColorsWithTint[i]
        var currentTint = 0,
            htmlStuff = '';
    
        for (var j = 0; j < current.tint.length; j++) {
            currentTint = current.tint[j]
            var htmlStuff = htmlStuff + '<td style="background-color:'+current.color+';opacity:'+currentTint+'"'+'></td>'
        }
    console.log(htmlStuff)
    jax_with_tint_body.append('<tr>'+
                              '<td>'+current.color+'</td>'+
                              '<td style="background-color:'+current.color+'"'+'>'+current.color+'</td>'+
                              htmlStuff +
                              '</tr>') 

}


for (var i = 0; i < jaxColors.length; i++) {
   //jax_brand_core_body.append('<tr><td>'+jaxColors[i]+'</td><td style="background-color:'+jaxColors[i]+'"'+'>'+jaxColors[i]+'</td></tr>') 
}

// %%
List<Map> PROTEINT_EFFECT_LIST = [
    [
        'value':'gain of function',
        'color': '#43B02A',
        'tint' : 1,
    ],
    [
        'value':'gain of function - predicted',
        'color': '#43B02A',
        'tint' : 0.5,
    ],
    [
        'value':'loss of function',
        'color': '#8A1B61',
        'tint' : 0.75,
    ],
    [
        'value':'loss of function - predicted',
        'color': '#8A1B61',
        'tint' : 0.5,
    ],
    [
        'value':'no effect',
        'color': '#DC582A',
        'tint' : 1,
    ],
    [
        'value':'no effect - predicted',
        'color': '#ED8B00',
        'tint' : 0.25,
    ],
    [
        'value':'unknown',
        'color': '#0085CA',
        'tint' : 1,
    ]
]
/*Map VARIANT_IMPACT_COLORS = ["deletion": '#ED8B00', "duplication": '#333F48', "frameshift": '#A2AAAD',
                                 "fusion"  : '#0085CA', "indel": '#9467bd', "insertion": '#43B02A', "missense": '#002D72',
                                 "none"    : '#7f7f7f', "nonsense": '#bcbd22', "splice site": '#17becf', "unknown": '#D0D3D4']*/
List<Map> IMPACT_LIST = [
    [
        'value': 'deletion',
        'color': '#D0D3D4',
        'tint': 1
    ],
    [
        'value': 'duplication',
        'color': '#ED8B00',
        'tint': 1
    ],
    [
        'value': 'frameshift',
        'color': '#8A1B61',
        'tint': 1,
    ],
    [
        'value': 'fusion',
        'color': '#43B02A',
        'tint': 1
    ],
    [
        'value': 'indel',
        'color': '#005151',
        'tint': 1
    ],
    [
        'value': 'insertion',
        'color': '#F1C400',
        'tint': 1
    ],
    [
        'value': 'missense',
        'color': '#0085CA',
        'tint': 1
    ],
    [
        'value': 'none',
        'color': '#D0D3D4',
        'tint': 1
    ],
    [
        'value': 'nonsense',
        'color': '#AB2328',
        'tint': 1
    ],
    [
        'value': 'splice site',
        'color': '#002D72',
        'tint': 1
    ],
    [
        'value' : 'unknown',
        'color': '#A2AAAD',
        'tint': 1
    ]
]

beakerx.protein_effect = ['protein_effect': PROTEINT_EFFECT_LIST]
beakerx.impact_list = ['impact_list': IMPACT_LIST]

// %%
%%js

var protein_effect_body = $('.protein_effect tbody'),
    impact_body = $('.impact tbody');

protein_effect_body.html('')
impact_body.html('')


var protein_effect = beakerx.protein_effect.protein_effect,
    impact_list = beakerx.impact_list.impact_list;


for (var i = 0; i < protein_effect.length; i++) {
    var current = protein_effect[i]
    protein_effect_body.append('<tr>'+
                                '<td>'+current.value+'</td>'+
                                '<td style="background-color:'+current.color+';opacity:'+current.tint+'"'+'></td>'+
                                '</tr>')
}

for (var i = 0; i < impact_list.length; i++) {
    var current = impact_list[i]
    impact_body.append('<tr>'+
                                '<td>'+current.value+'</td>'+
                                '<td style="background-color:'+current.color+';opacity:'+current.tint+'"'+'></td>'+
                                '</tr>')
}

// %%
/*
Case Reports/Case Series
Clinical Study
Clinical Study - Cohort
Clinical Study - Meta-analysis
Expanded access
FDA approved
FDA approved - Has Companion Diagnostic
FDA approved - On Companion Diagnostic
FDA contraindicated
Guideline
Phase 0
Phase I
Phase Ib/II
Phase II
Phase III
Preclinical
Preclinical - Cell culture
Preclinical - Cell line xenograft
Preclinical - Patient cell culture
Preclinical - Pdx
Preclinical - Pdx & cell culture
*/

List<Map> approval_status = [
    [
        value: 'Case Reports/Case Series',
        color: '#002D72',
        tint: 0.25,
        order: 11
    ],
    [
        value: 'Clinical Study',
        color: '#F1C400',
        tint: 1,
        order: 12
    ],
    [
        value: 'Clinical Study - Cohort',
        color: '#F1C400',
        tint: 0.75,
        order: 13
    ],
    [
        value: 'Clinical Study - Meta-analysis',
        color: '#F1C400',
        tint: 0.5,
        order: 14
    ],
    [
        value: 'Expanded access',
        color: '#2C2A29',
        tint: 0.75,
        order: 15
    ],
    [
        value: 'FDA approved',
        color: '#43B02A',
        tint: 1,
        order: 1
    ],
    [
        value: 'FDA approved - Has Companion Diagnostic',
        color: '#43B02A',
        tint: 0.75,
        order: 2
    ],
    [
        value: 'FDA approved - On Companion Diagnostic',
        color: '#43B02A',
        tint: 0.5,
        order: 3
    ],
    [
        value: 'FDA contraindicated',
        color: '#43B02A',
        tint: 0.25,
        order: 4
    ],
    [
        value: 'Guideline',
        color: '#8A1B61',
        tint: 1,
        order: 5
    ],
    [
        value: 'Phase 0',
        color: '#002D72',
        tint: 0.75,
        order: 6
    ],
    [
        value: 'Phase I',
        color: '#002D72',
        tint: 0.5,
        order: 7
    ],
    [
        value: 'Phase Ib/II',
        color: '#0085CA',
        tint: 1,
        order: 8
    ],
    [
        value: 'Phase II',
        color: '#0085CA',
        tint: 0.75,
        order: 9
    ],
    [
        value: 'Phase III',
        color: '#0085CA',
        tint: '0.5',
        order: 10
    ],
    [
        value: 'Preclinical',
        color: '#2C2A29',
        tint: 1,
        order: 16
    ],
    [
        value: 'Preclinical - Cell culture',
        color: '#2C2A29',
        tint: 0.75,
        order: 17
    ],
    [
        value: 'Preclinical - Cell line xenograft',
        color: '#2C2A29',
        tint: 0.5,
        order: 18
    ],
    [
        value: 'Preclinical - Patient cell culture',
        color: '#333F48',
        tint: 1,
        order: 19
    ],
    [
        value: 'Preclinical - Pdx',
        color: '#333F48',
        tint: 0.75,
        order: 20
    ],
    [
        value: 'Preclinical - Pdx & cell culture',
        color: '#333F48',
        tint: 0.5,
        order: 21
    ]   
]

beakerx.approval_status = ['approval_status': approval_status.sort {a,b -> a.order <=> b.order}]

// %%
%%js

var approval_status_body = $('.approval_status tbody');

approval_status_body.html('')

var approval_status = beakerx.approval_status.approval_status;

for (var i = 0; i < approval_status.length; i++) {
    var current = approval_status[i]
    approval_status_body.append('<tr>'+
                                '<td>'+current.value+'</td>'+
                                '<td style="background-color:'+current.color+';opacity:'+current.tint+'"'+'></td>'+
                                '</tr>')
}
